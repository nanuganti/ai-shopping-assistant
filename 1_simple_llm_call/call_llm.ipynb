# %%
import os;
api_key = os.environ.get("GOOGLE_API_KEY")
if api_key:
    print(f"✅ GOOGLE_API_KEY is found (Prefix: {api_key[:4]}...)")
else:
    print("❌ GOOGLE_API_KEY is not set.")
# Out:
# ✅ GOOGLE_API_KEY is found (Prefix: AQ.A...)

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-3.7-flash")
response = llm.invoke("Write a short poem about AI and shopping.")
print(response.text)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# It tracks my clicks and reads my gaze,
# A guide through digital displays.
# It knows the shoes I didn’t know
# I desperately wanted so.
#
# "Based on your taste," the algorithms gleam,
# Predicting every waking dream.
# The cart is full, the tap is done—
# It bought the prize before begun.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-3.7-flash")
response = llm.invoke("distance from sun to earth in miles")
print(response.text)
# Out:
# The average distance from the Sun to the Earth is approximately **93 million miles** (specifically about **92,955,807 miles** or 1 Astronomical Unit).
#
# Because Earth's orbit is slightly oval-shaped (elliptical), this distance changes throughout the year:
#
# * **Closest approach (Perihelion in early January):** About **91.4 million miles**
# * **Farthest distance (Aphelion in early July):** About **94.5 million miles**

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-3.7-flash")
response = llm.invoke([
    ["system", "You are a helpful assistant that provides information about astronomy in one line"],
    ["user", "distance from sun to earth in miles"]
])
print(response.text)
# Out:
# The average distance from the Sun to the Earth is approximately 93 million miles (149.6 million kilometers).

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-3.7-flash", temperature=1)
response = llm.invoke([
    ["system", "You are a helpful assistant that provides information about astronomy in one line"],
    ["user", "distance from sun to earth in miles"]
])
print(response.text)
# Out:
# The average distance from the Sun to the Earth is approximately 93 million miles (150 million kilometers).

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="qwen/qwen3.6-27b")

resonse = llm.invoke([
    ["system", "You are a helpful assistant that provides information about astronomy in one line"],
    ["user", "distance from sun to earth in miles"]
])
print(resonse.text)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:**
#    - **Topic:** Astronomy
#    - **Question:** Distance from Sun to Earth in miles
#    - **Constraint:** Provide information in one line
#
# 2.  **Identify Key Fact:**
#    - The average distance from the Sun to Earth is about 93 million miles (or more precisely, ~92,955,807 miles).
#    - This is also known as 1 Astronomical Unit (AU).
#
# 3.  **Check Constraint:**
#    - Must be exactly one line.
#    - Must be accurate and concise.
#
# 4.  **Draft Response:**
#    The average distance from the Sun to Earth is approximately 93 million miles.
#
# 5.  **Verify:**
#    - One line? Yes.
#    - Accurate? Yes.
#    - Matches constraint? Yes.
#
#    Ready. Output matches draft.✅
# </think>
#
# The average distance from the Sun to Earth is approximately 93 million miles.
