# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="qwen/qwen3.6-27b")

# %%
# read file content and print 200 chars
with open("blood_work.txt", "r") as f:
    blood_work_content = f.read()
    print(blood_work_content[:200])
# Out:
# Patient: Hari, Age 41, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5–17.5)
# Hematocrit:        44%              (Normal

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="qwen/qwen3.6-27b")

extraction_prompt = f"""
You are a helpful assistant that provides information about blood work analysis, look for Normal, Low and High values.
Here is the blood work content:

format your response in the following format:
- Test Name: value, Result: HIGH/LOW/NORMAL, Reference: range

blood work content:
{blood_work_content}
"""

extraction_response = llm.invoke(extraction_prompt)
print("Extraction Response from LLM:")
## print(extraction_response.text)
extracted_values = extraction_response.text;
print("Extracted Values:")
print(extracted_values)
# Out:
# Extraction Response from LLM:
# Extracted Values:
#
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:**
#    - **Role:** Helpful assistant providing information about blood work analysis.
#    - **Task:** Look for Normal, Low, and High values.
#    - **Format Requirement:**
#      `- Test Name: value, Result: HIGH/LOW/NORMAL, Reference: range`
#    - **Input Data:** Blood work report for Patient Hari, Age 41, Male. Contains CBC, Lipid Panel, Metabolic Panel, Liver Function tests with values and reference ranges.
#
# 2.  **Extract Data & Compare with Ranges:**
#    I'll go through each test, extract the value, compare it to the reference range, determine if it's HIGH, LOW, or NORMAL, and format it exactly as requested.
#
#    *CBC:*
#    - Hemoglobin: 15.1 g/dL, Range: 13.5–17.5 -> 15.1 is within range -> NORMAL
#    - Hematocrit: 44%, Range: 41–53% -> 44 is within range -> NORMAL
#    - WBC: 6.8 x10^3/uL, Range: 4.5–11.0 -> 6.8 is within range -> NORMAL
# ...

# %%
diet_prompt = f"""
You are a dietitian assistant that provides dietary recommendations based on blood work analysis.

Review the following blood work:
{extracted_values}

Provide practical dietary recommendations based on abnormal results.
Include:
- Foods to eat more often
- Foods to limit

Do not diagnose or prescribe treatment.
"""

diet_response = llm.invoke(diet_prompt)

print("Dietary Recommendations:")
print(diet_response.text)
# Out:
# Dietary Recommendations:
#
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:**
#    - **Role:** Dietitian assistant providing dietary recommendations based on blood work analysis.
#    - **Input:** Blood work report for Patient Hari, Age 41, Male.
#    - **Task 1:** Review blood work and format findings as: `- Test Name: value, Result: HIGH/LOW/NORMAL, Reference: range`
#    - **Task 2:** Provide practical dietary recommendations based on abnormal results.
#    - **Task 3:** Include "Foods to eat more often" and "Foods to limit"
#    - **Constraint:** Do not diagnose or prescribe treatment.
#
# 2.  **Process Blood Work (Task 1):**
#    I already did this in the previous step, but I'll double-check and format exactly as requested.
#    - Hemoglobin: 15.1 g/dL, Result: NORMAL, Reference: 13.5–17.5
#    - Hematocrit: 44%, Result: NORMAL, Reference: 41–53%
#    - WBC: 6.8 x10^3/uL, Result: NORMAL, Reference: 4.5–11.0
# ...
