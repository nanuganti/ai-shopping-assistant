# %%
import chromadb

client = chromadb.Client()

# %%
collection = client.create_collection("news_articles")

# %%
collection.add(
    ids=["1", "2", "3", "4", "5"],
    documents=[
        "The stock market saw a significant increase today, with major indices closing at record highs.",
        "A new study reveals the benefits of a plant-based diet for long-term health.",
        "The local football team won their championship game in a thrilling overtime victory.",
        "Scientists have discovered a new species of deep-sea fish in the Pacific Ocean.",
        "The city council has approved a new public transportation initiative to reduce traffic congestion."
        "spaceX has successfully launched its latest rocket, marking a milestone in commercial space travel."
    ],
    metadatas=[
        {"source": "Financial Times", "date": "2023-10-01"},
        {"source": "Health Journal", "date": "2023-10-02"},
        {"source": "Sports Daily", "date": "2023-10-03"},
        {"source": "Science News", "date": "2023-10-04"},
        {"source": "City Council Report", "date": "2023-10-05"}
    ]);
# Out:
# /Users/nanuganti/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:17<00:00, 4.89MiB/s]

# %%
## fetch documents and embeddings from the collection
results = collection.get(
    ids=["1", "2", "3", "4", "5"],
    include=["documents", "metadatas", "embeddings"]
)

## print collection and first 10 chars of each embeding 

for i, doc in enumerate(results['documents']):
    print(f"Document ID: {results['ids'][i]}")
    print(f"Document: {doc}")
    print(f"Metadata: {results['metadatas'][i]}")
    print(f"Embedding: {str(emb)[:100]}...") 
    print("-" * 40)
# Out:
# Document ID: 1
# Document: The stock market saw a significant increase today, with major indices closing at record highs.
# Metadata: {'source': 'Financial Times', 'date': '2023-10-01'}
# Embedding: [-2.31144624e-03 -9.69526917e-03  7.99563527e-02  6.21422157e-02
#   2.79168058e-02  1.09187374e-02  2...
# ----------------------------------------
# Document ID: 2
# Document: A new study reveals the benefits of a plant-based diet for long-term health.
# Metadata: {'source': 'Health Journal', 'date': '2023-10-02'}
# Embedding: [-2.31144624e-03 -9.69526917e-03  7.99563527e-02  6.21422157e-02
#   2.79168058e-02  1.09187374e-02  2...
# ----------------------------------------
# Document ID: 3
# Document: The local football team won their championship game in a thrilling overtime victory.
# Metadata: {'date': '2023-10-03', 'source': 'Sports Daily'}
# Embedding: [-2.31144624e-03 -9.69526917e-03  7.99563527e-02  6.21422157e-02
#   2.79168058e-02  1.09187374e-02  2...
# ----------------------------------------
# Document ID: 4
# Document: Scientists have discovered a new species of deep-sea fish in the Pacific Ocean.
# Metadata: {'date': '2023-10-04', 'source': 'Science News'}
# Embedding: [-2.31144624e-03 -9.69526917e-03  7.99563527e-02  6.21422157e-02
#   2.79168058e-02  1.09187374e-02  2...
# ----------------------------------------
# Document ID: 5
# Document: The city council has approved a new public transportation initiative to reduce traffic congestion.
# Metadata: {'date': '2023-10-05', 'source': 'City Council Report'}
# Embedding: [-2.31144624e-03 -9.69526917e-03  7.99563527e-02  6.21422157e-02
#   2.79168058e-02  1.09187374e-02  2...
# ----------------------------------------
